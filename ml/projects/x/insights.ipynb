# %% [markdown]
# # Insights

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
posts = pd.read_csv('posts.csv')
posts.head()
# Out:
#                post_id               date  \
# 0  1939692818768724028  Mon, Jun 30, 2025
# 1  1937876171934347337  Wed, Jun 25, 2025
# 2  1937598816963952922  Tue, Jun 24, 2025
# 3  1937561131737928009  Tue, Jun 24, 2025
# 4  1937535378254180450  Tue, Jun 24, 2025
#
#                                            post_text  \
# 0  @rudrankriyam snuff is one of my favorite song...
# 1                                    🚨 heat advisory
# 2        PEOPLE OF THE WORLD https://t.co/Mv5u8G6dTJ
# 3  this is an amazing read. @AirbnbEng shares an ...
# 4  did some rearranging. come say hi over at @sem...
#
#                                                 link  impressions  likes  \
# 0  https://x.com/bodhichristian/status/1939692818...          101      0
# 1  https://x.com/bodhichristian/status/1937876171...          279      4
# 2  https://x.com/bodhichristian/status/1937598816...          393      1
# 3  https://x.com/bodhichristian/status/1937561131...          775      6
# 4  https://x.com/bodhichristian/status/1937535378...          438      4
#
#    engagements  bookmarks  share  new follows  replies  reposts  \
# 0            6          0      0            0        1        0
# 1            6          0      0            0        0        0
# 2            9          0      0            0        0        0
# 3           16          1      0            0        0        1
# 4            4          0      0            0        0        0
#
#    profile_visits  detail_expands  url_clicks  hashtag_clicks  \
# 0               1               4           0               0
# 1               0               2           0               0
# 2               2               1           0               0
# 3               6               3           0               0
# 4               0               0           0               0
#
#    permalink_clicks
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
columns = ['post_id', 'link', 'url_clicks', 'hashtag_clicks', 'permalink_clicks']
posts_df = posts.drop(columns, axis=1)
posts_df.head()
# Out:
#                 date                                          post_text  \
# 0  Mon, Jun 30, 2025  @rudrankriyam snuff is one of my favorite song...
# 1  Wed, Jun 25, 2025                                    🚨 heat advisory
# 2  Tue, Jun 24, 2025        PEOPLE OF THE WORLD https://t.co/Mv5u8G6dTJ
# 3  Tue, Jun 24, 2025  this is an amazing read. @AirbnbEng shares an ...
# 4  Tue, Jun 24, 2025  did some rearranging. come say hi over at @sem...
#
#    impressions  likes  engagements  bookmarks  share  new follows  replies  \
# 0          101      0            6          0      0            0        1
# 1          279      4            6          0      0            0        0
# 2          393      1            9          0      0            0        0
# 3          775      6           16          1      0            0        0
# 4          438      4            4          0      0            0        0
#
#    reposts  profile_visits  detail_expands
# 0        0               1               4
# 1        0               0               2
# 2        0               2               1
# 3        1               6               3
# 4        0               0               0
